# %%
# - SET DE DATOS JUNTOS - 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

actions = pd.read_csv('/home/dai/Documentos/DATOS/2019/tp1/actions.csv')
actions.head()
# Out:
#    auction_type_id              country                        date  \
# 0              NaN  6333597102633388268  2019-03-11 14:18:33.290763
# 1              NaN  6333597102633388268  2019-03-11 14:18:34.440157
# 2              NaN  6333597102633388268  2019-03-11 14:18:35.862360
# 3              NaN  6333597102633388268  2019-03-11 14:18:36.167163
# 4              NaN  6333597102633388268  2019-03-11 14:18:37.728590
#
#              device_id  platform  ref_type_id  source_id
# 0  6059599345986491085         1            1          0
# 1  1115994996230693426         1            1          0
# 2  7463856250762200923         1            1          0
# 3  7829815350267792040         1            1          0
# 4  1448534231953777480         1            1          0

# %%
clicks = pd.read_csv('/home/dai/Documentos/DATOS/2019/tp1/clicks.csv')
clicks.head()
# Out:
#    advertiser_id  action_id  source_id                   created  \
# 0              2        NaN          4  2019-03-06T22:42:12.755Z
# 1              0        NaN          0  2019-03-08T10:24:30.641Z
# 2              0        NaN          0  2019-03-08T15:24:16.069Z
# 3              2        NaN          3  2019-03-06T03:08:51.543Z
# 4              2        NaN          3  2019-03-06T03:32:55.570Z
#
#           country_code  latitude  longitude wifi_connection  carrier_id  \
# 0  6333597102633388268  1.205689   1.070234           False         1.0
# 1  6333597102633388268  1.218924   1.071209           False         4.0
# 2  6333597102633388268  1.205689   1.070234           False         6.0
# 3  6333597102633388268  1.205689   1.070234           False        45.0
# 4  6333597102633388268  1.205689   1.070234           False        45.0
#
#                           trans_id      os_minor  agent_device      os_major  \
# ...

# %%
installs = pd.read_csv('/home/dai/Documentos/DATOS/2019/tp1/installs.csv')
installs.head(6)
# Out:
#                    created  application_id             ref_type  \
# 0  2019-03-13 01:43:33.445               0  1891515180541284343
# 1  2019-03-13 04:58:35.078               0  1891515180541284343
# 2  2019-03-13 04:20:57.666               0  1891515180541284343
# 3  2019-03-13 04:20:57.698               0  1891515180541284343
# 4  2019-03-10 22:24:56.684               0  1891515180541284343
# 5  2019-03-10 22:24:57.545               0  1891515180541284343
#
#               ref_hash  click_hash attributed implicit   device_countrycode  \
# 0  8464844987297247076         NaN      False    False  6333597102633388268
# 1  3250564871270161533         NaN      False    False  6333597102633388268
# 2  7953318831018100268         NaN      False     True  6333597102633388268
# 3  7953318831018100268         NaN      False    False  6333597102633388268
# 4  8355110941557237501         NaN      False     True  6333597102633388268
# ...

# %%
events = pd.read_csv('/home/dai/Documentos/DATOS/2019/tp1/events.csv')
events.head(6)
# Out:
# /home/dai/anaconda2/lib/python2.7/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (12,18,19) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                       date  event_id             ref_type  \
# 0  2019-03-05 00:09:36.966         0  1891515180541284343
# 1  2019-03-05 00:09:38.920         1  1891515180541284343
# 2  2019-03-05 00:09:26.195         0  1891515180541284343
# 3  2019-03-05 00:09:31.107         2  1891515180541284343
# 4  2019-03-09 21:00:36.585         3  1891515180541284343
# 5  2019-03-09 20:29:45.449         4  1891515180541284343
#
#               ref_hash  application_id attributed   device_countrycode  \
# 0  2688759737656491380              38      False  6333597102633388268
# 1  2688759737656491380              38      False  6333597102633388268
# 2  2688759737656491380              38      False  6333597102633388268
# ...

# %%
# - ACTIONS-
# Top five 
actions.sort_values('country',ascending=False).head(5)
# Out:
#           auction_type_id              country                        date  \
# 0                     NaN  6333597102633388268  2019-03-11 14:18:33.290763
# 13047551              NaN  6333597102633388268  2019-03-06 01:40:52.509735
# 13047549              NaN  6333597102633388268  2019-03-06 01:40:48.738243
# 13047548              NaN  6333597102633388268  2019-03-06 01:40:48.705565
# 13047547              NaN  6333597102633388268  2019-03-06 01:40:47.918749
#
#                     device_id  platform  ref_type_id  source_id
# 0         6059599345986491085         1            1          0
# 13047551  2580513050335528732         1            1          0
# 13047549  8292793494956750501         1            1          0
# 13047548  2898055894659265616         2            7          0
# 13047547  7735845193957092626         1            1          0

# %%
actions = actions['country'].value_counts()

# %%
actions.dtypes
# Out:
# dtype('int64')

# %%
# - CLICKS - 
clicks.dtypes
# Out:
# advertiser_id        int64
# action_id          float64
# source_id            int64
# created             object
# country_code         int64
# latitude           float64
# longitude          float64
# wifi_connection       bool
# carrier_id         float64
# trans_id            object
# os_minor           float64
# agent_device       float64
# os_major           float64
# specs_brand          int64
# brand              float64
# timeToClick        float64
# touchX             float64
# touchY             float64
# ref_type             int64
# ref_hash             int64
# dtype: object

# %%
clicks.groupby('advertiser_id').count()['created'].plot(figsize=(14,4));

# %%
clicks.groupby('agent_device').count()['created'].plot(figsize=(14,4));

# %%
clicks.sort_values('action_id', ascending=False).head(6)
# Out:
#    advertiser_id  action_id  source_id                   created  \
# 0              2        NaN          4  2019-03-06T22:42:12.755Z
# 1              0        NaN          0  2019-03-08T10:24:30.641Z
# 2              0        NaN          0  2019-03-08T15:24:16.069Z
# 3              2        NaN          3  2019-03-06T03:08:51.543Z
# 4              2        NaN          3  2019-03-06T03:32:55.570Z
# 5              5        NaN          4  2019-03-07T18:02:25.833Z
#
#           country_code  latitude  longitude wifi_connection  carrier_id  \
# 0  6333597102633388268  1.205689   1.070234           False         1.0
# 1  6333597102633388268  1.218924   1.071209           False         4.0
# 2  6333597102633388268  1.205689   1.070234           False         6.0
# 3  6333597102633388268  1.205689   1.070234           False        45.0
# 4  6333597102633388268  1.205689   1.070234           False        45.0
# 5  6333597102633388268  1.209638   1.064208           False        27.0
#
# ...

# %%
clicks.sort_values('advertiser_id', ascending=False).head(6)
# Out:
#        advertiser_id  action_id  source_id                   created  \
# 8862               8        NaN          1  2019-03-06T03:02:40.352Z
# 17652              7        NaN         10  2019-03-08T08:28:29.578Z
# 21131              7        NaN         10  2019-03-13T09:37:48.404Z
# 5                  5        NaN          4  2019-03-07T18:02:25.833Z
# 13175              3        NaN          6  2019-03-11T01:44:47.509Z
# 17517              3        NaN          0  2019-03-10T05:43:40.068Z
#
#               country_code  latitude  longitude wifi_connection  carrier_id  \
# 8862   6333597102633388268  1.209638   1.064208           False        28.0
# 17652  6333597102633388268  1.205689   1.070234           False         NaN
# 21131  6333597102633388268  1.205689   1.070234           False         NaN
# 5      6333597102633388268  1.209638   1.064208           False        27.0
# 13175  6333597102633388268  1.205689   1.070234           False        13.0
# ...

# %%
# -INSTALLS- 
installs.dtypes
# Out:
# created                object
# application_id          int64
# ref_type                int64
# ref_hash                int64
# click_hash            float64
# attributed               bool
# implicit                 bool
# device_countrycode      int64
# device_brand          float64
# device_model          float64
# session_user_agent     object
# user_agent             object
# event_uuid             object
# kind                   object
# wifi                   object
# trans_id               object
# ip_address              int64
# device_language       float64
# dtype: object

# %%
# Number of created per user_agent -  ARREGLAR EL TEMA DEL USUARIO-
installs.groupby('user_agent').count()['created'].plot(figsize=(14,4));
#-CONSULTAR VARIABLES Y DISFERENCIAS-
# Number of ip_address  by user_agent
installs['user_agent'].value_counts()[0:19].plot(kind='bar',figsize=(14,4));

# %%
# Most common application_id 
installs['application_id'].value_counts().sort_index().plot(kind='bar',figsize=(14,4));

# %%
# Number of ip_address  by user_agent
installs['user_agent'].value_counts()[0:19].plot(kind='bar',figsize=(14,4));

# %%
# Number of ip_address  by user_agent -CONSULTAR-
installs.groupby('user_agent').sum()['ip_address'].sort_values(ascending=False)[0:19].plot(kind='bar',figsize=(14,4));

# Number of ip_address  by user_agent
#installs['user_agent'].value_counts()[0:19].plot(kind='bar',figsize=(14,4));

# %%
# -EVENTS -
events.dtypes
# Out:
# date                   object
# event_id                int64
# ref_type                int64
# ref_hash                int64
# application_id          int64
# attributed               bool
# device_countrycode      int64
# device_os_version     float64
# device_brand          float64
# device_model          float64
# device_city           float64
# session_user_agent    float64
# trans_id               object
# user_agent            float64
# event_uuid             object
# carrier               float64
# kind                  float64
# device_os             float64
# wifi                   object
# connection_type        object
# ip_address              int64
# device_language       float64
# dtype: object

# %%
# Top five events
events.sort_values('event_id',ascending=False).head(5)
# Out:
#                             date  event_id             ref_type  \
# 2440139  2019-03-11 10:57:09.071       712  1891515180541284343
# 2440142  2019-03-11 19:32:52.769       712  1891515180541284343
# 2069671  2019-03-13 20:01:30.436       701  1891515180541284343
# 2069261  2019-03-12 14:56:54.996       700  1891515180541284343
# 2069024  2019-03-13 05:11:54.463       700  1891515180541284343
#
#                     ref_hash  application_id attributed   device_countrycode  \
# 2440139  7949872891569861523             257      False  6333597102633388268
# 2440142  7949872891569861523             257      False  6333597102633388268
# 2069671  7041936166779093560             317      False  6333597102633388268
# 2069261    50525696202010603             317      False  6333597102633388268
# 2069024  6359493934198436655             317      False  6333597102633388268
#
#          device_os_version  device_brand  device_model       ...        \
# ...

# %%
#Cantidad de conections con wifi 
events['wifi'].value_counts()[:10].plot('bar');

# %%
#Tipos de conectios con sus cantidades
events['connection_type'].value_counts()[:10].plot('bar');

# %%
events['date'].value_counts()[:10].plot('bar');

# %%
#Quiero ver como se distribuye la cantidad de eventos que realizan conversiones según la pplicacion_id y date.
eventsDate = events.filter(items = ['event_id', 'application_id', 'date']).groupby(['event_id', 'application_id'])
conteoEventsDate = eventsDate.count().reset_index()

# %%
#Realizamos una visualizacion de los eventos a traves del tiempo
#Quiero aclarar que se realizo una agrupacion dia a dia para realizar este plot
plt = events.groupby('date').count()['event_id'].plot(figsize=(14,4));
plt.set_xlabel('date')
plt.set_ylabel('Cantidad de eventos')
plt.set_title('Cantidad de eventos por date')

# %%
plt = events.groupby('event_id').count()['wifi'].plot(figsize=(14,4));
plt.set_xlabel('events_id')
plt.set_ylabel('Cantidad de conexiones wifi')
plt.set_title('Cantidad de eventos por conexiones wifi')
