# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline


auctions = pd.read_csv('/home/gaston/Documentos/Orga de Datos/set de datos 1C2019/auctions/train.csv.gzip', encoding='latin-1')
auctions.head()
# Out:
#    auction_type_id              country                        date  \
# 0              NaN  6333597102633388268  2019-03-11 14:18:33.290763
# 1              NaN  6333597102633388268  2019-03-11 14:18:34.440157
# 2              NaN  6333597102633388268  2019-03-11 14:18:35.862360
# 3              NaN  6333597102633388268  2019-03-11 14:18:36.167163
# 4              NaN  6333597102633388268  2019-03-11 14:18:37.728590
#
#              device_id  platform  ref_type_id  source_id
# 0  6059599345986491085         1            1          0
# 1  1115994996230693426         1            1          0
# 2  7463856250762200923         1            1          0
# 3  7829815350267792040         1            1          0
# 4  1448534231953777480         1            1          0

# %%
auctions['source_id'].value_counts().head(10)
# Out:
# 0    13354597
# 1     4016739
# 5     1466494
# 2      582083
# 6      151406
# Name: source_id, dtype: int64

# %%
auctions.shape # dimension de la matriz
# Out:
# (19571319, 7)

# %%
auctions_columns = auctions.columns

# %%
auctions_columns # ver columnas
# Out:
# Index(['auction_type_id', 'country', 'date', 'device_id', 'platform',
#        'ref_type_id', 'source_id'],
#       dtype='object')

# %%
auctions['country'].value_counts().head() #elementos de la columna country
# Out:
# 6333597102633388268    19571319
# Name: country, dtype: int64

# %%
#como los elementos de la columna country son iguales, se pueden eliminar, son datos innecesarios

auctions=auctions.drop('country',axis='columns')

# %%
auctions.head()
# Out:
#    auction_type_id                        date            device_id  platform  \
# 0              NaN  2019-03-11 14:18:33.290763  6059599345986491085         1
# 1              NaN  2019-03-11 14:18:34.440157  1115994996230693426         1
# 2              NaN  2019-03-11 14:18:35.862360  7463856250762200923         1
# 3              NaN  2019-03-11 14:18:36.167163  7829815350267792040         1
# 4              NaN  2019-03-11 14:18:37.728590  1448534231953777480         1
#
#    ref_type_id  source_id
# 0            1          0
# 1            1          0
# 2            1          0
# 3            1          0
# 4            1          0

# %%
auctions_typeId = auctions['auction_type_id']

# %%
auctions_typeId.value_counts().head() # elementos de la columna auction_type_id
# Out:
# Series([], Name: auction_type_id, dtype: int64)

# %%
auctions_typeId.isnull().sum()
# Out:
# 19571319

# %%
# como todos los elementos de la columna auction_type_id son nulos los puedo eliminar

auctions=auctions.drop('auction_type_id',axis='columns')

# %%
auctions.head()
# Out:
#                          date            device_id  platform  ref_type_id  \
# 0  2019-03-11 14:18:33.290763  6059599345986491085         1            1
# 1  2019-03-11 14:18:34.440157  1115994996230693426         1            1
# 2  2019-03-11 14:18:35.862360  7463856250762200923         1            1
# 3  2019-03-11 14:18:36.167163  7829815350267792040         1            1
# 4  2019-03-11 14:18:37.728590  1448534231953777480         1            1
#
#    source_id
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0

# %%
click = pd.read_csv('/home/gaston/Documentos/Orga de Datos/set de datos 1C2019/click/train.csv.gzip', encoding='latin-1')
click.head()
# Out:
#    advertiser_id  action_id  source_id                   created  \
# 0              2        NaN          4  2019-03-06T22:42:12.755Z
# 1              0        NaN          0  2019-03-08T10:24:30.641Z
# 2              0        NaN          0  2019-03-08T15:24:16.069Z
# 3              2        NaN          3  2019-03-06T03:08:51.543Z
# 4              2        NaN          3  2019-03-06T03:32:55.570Z
#
#           country_code  latitude  longitude  wifi_connection  carrier_id  \
# 0  6333597102633388268  1.205689   1.070234            False         1.0
# 1  6333597102633388268  1.218924   1.071209            False         4.0
# 2  6333597102633388268  1.205689   1.070234            False         6.0
# 3  6333597102633388268  1.205689   1.070234            False        45.0
# 4  6333597102633388268  1.205689   1.070234            False        45.0
#
#                           trans_id      os_minor  agent_device      os_major  \
# ...

# %%
click.shape
# Out:
# (26351, 20)

# %%
click_nombreCol = click.columns
click_nombreCol
# Out:
# Index(['advertiser_id', 'action_id', 'source_id', 'created', 'country_code',
#        'latitude', 'longitude', 'wifi_connection', 'carrier_id', 'trans_id',
#        'os_minor', 'agent_device', 'os_major', 'specs_brand', 'brand',
#        'timeToClick', 'touchX', 'touchY', 'ref_type', 'ref_hash'],
#       dtype='object')

# %%
clickActionID= click['action_id'] # action id
clickActionID.value_counts().head()
# Out:
# Series([], Name: action_id, dtype: int64)

# %%
clickActionID.isnull().sum() # como es nula los elementos, se puede eliminar
# Out:
# 26351

# %%
click = click.drop('action_id',axis='columns') # como es nula los elementos, se puede eliminar

# %%
click_country = click['country_code']
click_country.value_counts().head()
# Out:
# 6333597102633388268    26351
# Name: country_code, dtype: int64

# %%
click = click.drop('country_code',axis='columns') # como los elementos son iguales, se puede eliminar#un solo pais

# %%
click.head()
# Out:
#    advertiser_id  source_id                   created  latitude  longitude  \
# 0              2          4  2019-03-06T22:42:12.755Z  1.205689   1.070234
# 1              0          0  2019-03-08T10:24:30.641Z  1.218924   1.071209
# 2              0          0  2019-03-08T15:24:16.069Z  1.205689   1.070234
# 3              2          3  2019-03-06T03:08:51.543Z  1.205689   1.070234
# 4              2          3  2019-03-06T03:32:55.570Z  1.205689   1.070234
#
#    wifi_connection  carrier_id                         trans_id      os_minor  \
# 0            False         1.0  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18
# 1            False         4.0  MMHTOJ6qKAOeIH_Eywh1KIcCaxtO9oM  3.025219e+18
# 2            False         6.0  vIrEIdf9izUaWdAri6Ezk7T3nHFvNQU  5.975656e+18
# 3            False        45.0  YaKxxEAs2UmZhSpRfiCO9Zpa82B_AKM  6.768137e+18
# 4            False        45.0  X5XTOcYQovkl6yadYdAD7xioVGU9jiY  6.768137e+18
#
# ...

# %%
## elimino columnas para trabajar con datos mas pequeños
click = click.drop('timeToClick',axis='columns')
click = click.drop( 'touchX',axis='columns')
click = click.drop('touchY',axis='columns')
click = click.drop('latitude',axis='columns')
click = click.drop('longitude',axis='columns')
click.head()
# Out:
#    advertiser_id  source_id                   created  wifi_connection  \
# 0              2          4  2019-03-06T22:42:12.755Z            False
# 1              0          0  2019-03-08T10:24:30.641Z            False
# 2              0          0  2019-03-08T15:24:16.069Z            False
# 3              2          3  2019-03-06T03:08:51.543Z            False
# 4              2          3  2019-03-06T03:32:55.570Z            False
#
#    carrier_id                         trans_id      os_minor  agent_device  \
# 0         1.0  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18           NaN
# 1         4.0  MMHTOJ6qKAOeIH_Eywh1KIcCaxtO9oM  3.025219e+18           NaN
# 2         6.0  vIrEIdf9izUaWdAri6Ezk7T3nHFvNQU  5.975656e+18           NaN
# 3        45.0  YaKxxEAs2UmZhSpRfiCO9Zpa82B_AKM  6.768137e+18           NaN
# 4        45.0  X5XTOcYQovkl6yadYdAD7xioVGU9jiY  6.768137e+18           NaN
#
#        os_major          specs_brand  brand             ref_type  \
# ...

# %%
click = click.drop('specs_brand',axis='columns')
click.head()
# Out:
#    advertiser_id  source_id                   created  wifi_connection  \
# 0              2          4  2019-03-06T22:42:12.755Z            False
# 1              0          0  2019-03-08T10:24:30.641Z            False
# 2              0          0  2019-03-08T15:24:16.069Z            False
# 3              2          3  2019-03-06T03:08:51.543Z            False
# 4              2          3  2019-03-06T03:32:55.570Z            False
#
#    carrier_id                         trans_id      os_minor  agent_device  \
# 0         1.0  iGgClCM9exiHF4K31g94XmvHEBSLKIY  6.768137e+18           NaN
# 1         4.0  MMHTOJ6qKAOeIH_Eywh1KIcCaxtO9oM  3.025219e+18           NaN
# 2         6.0  vIrEIdf9izUaWdAri6Ezk7T3nHFvNQU  5.975656e+18           NaN
# 3        45.0  YaKxxEAs2UmZhSpRfiCO9Zpa82B_AKM  6.768137e+18           NaN
# 4        45.0  X5XTOcYQovkl6yadYdAD7xioVGU9jiY  6.768137e+18           NaN
#
#        os_major  brand             ref_type             ref_hash
# ...

# %%
click = click.drop('wifi_connection',axis='columns')
click = click.drop('trans_id',axis='columns')
click = click.drop('ref_type',axis='columns')
click = click.drop('ref_hash',axis='columns')
click.head()
# Out:
#    advertiser_id  source_id                   created  carrier_id  \
# 0              2          4  2019-03-06T22:42:12.755Z         1.0
# 1              0          0  2019-03-08T10:24:30.641Z         4.0
# 2              0          0  2019-03-08T15:24:16.069Z         6.0
# 3              2          3  2019-03-06T03:08:51.543Z        45.0
# 4              2          3  2019-03-06T03:32:55.570Z        45.0
#
#        os_minor  agent_device      os_major  brand
# 0  6.768137e+18           NaN  3.072849e+18    NaN
# 1  3.025219e+18           NaN  1.774085e+18    NaN
# 2  5.975656e+18           NaN  3.072849e+18    NaN
# 3  6.768137e+18           NaN  3.072849e+18    NaN
# 4  6.768137e+18           NaN  3.072849e+18    NaN

# %%
## merge de Auctions y Click por source_id
mergeAuctions_click =pd.merge(click, auctions, on='source_id', how='outer')
##mergeAuctions_click =pd.merge(click, auctions, left_on='source_id', right_on='source_id')
#mergeAuctions_click =pd.merge(click, auctions, on='source_id')

#mergeAuctions_click.head()
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-25-9ffead62969c> in <module>
#       1 ## merge de Auctions y Click por source_id
# ----> 2 mergeAuctions_click =pd.merge(click, auctions, on='source_id', how='outer')
#       3 ##mergeAuctions_click =pd.merge(click, auctions, left_on='source_id', right_on='source_id')
#       4 #mergeAuctions_click =pd.merge(click, auctions, on='source_id')
#       5
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#      60                          copy=copy, indicator=indicator,
#      61                          validate=validate)
# ---> 62     return op.get_result()
#      63
#      64
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/merge.py in get_result(self)
# ...
